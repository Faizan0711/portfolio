# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,f1_score,precision_score

# %%
df = pd.read_csv("../credit_risk_data.csv")

# %%
df.head()
# Out:
#        LIMIT_BAL  AGE  SEX  EDUCATION  MARRIAGE  UTILIZATION_RATE  \
# 0  174835.707651   60    1          1         1          0.086712
# 1  143086.784941   21    2          1         1          0.178230
# 2  182384.426905   24    1          1         2          0.358530
# 3  226151.492820   50    1          1         2          0.523811
# 4  138292.331264   32    2          3         3          0.322966
#
#    PAY_DELAY_MONTHS  default
# 0                 1        0
# 1                 1        1
# 2                 0        1
# 3                 0        0
# 4                 3        1

# %%
df.dtypes
# Out:
# LIMIT_BAL           float64
# AGE                   int64
# SEX                   int64
# EDUCATION             int64
# MARRIAGE              int64
# UTILIZATION_RATE    float64
# PAY_DELAY_MONTHS      int64
# default               int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LIMIT_BAL         5000 non-null   float64
#  1   AGE               5000 non-null   int64
#  2   SEX               5000 non-null   int64
#  3   EDUCATION         5000 non-null   int64
#  4   MARRIAGE          5000 non-null   int64
#  5   UTILIZATION_RATE  5000 non-null   float64
#  6   PAY_DELAY_MONTHS  5000 non-null   int64
#  7   default           5000 non-null   int64
# dtypes: float64(2), int64(6)
# memory usage: 312.6 KB

# %%
df.describe()
# Out:
#            LIMIT_BAL         AGE          SEX    EDUCATION    MARRIAGE  \
# count    5000.000000  5000.00000  5000.000000  5000.000000  5000.00000
# mean   150352.628895    44.82140     1.399000     1.919200     1.67180
# std     49620.509995    14.06722     0.489742     0.885228     0.66013
# min     20000.000000    21.00000     1.000000     1.000000     1.00000
# 25%    117104.748117    33.00000     1.000000     1.000000     1.00000
# 50%    150673.279595    45.00000     1.000000     2.000000     2.00000
# 75%    183300.530353    57.00000     2.000000     3.000000     2.00000
# max    346311.885322    69.00000     2.000000     4.000000     3.00000
#
#        UTILIZATION_RATE  PAY_DELAY_MONTHS      default
# count       5000.000000       5000.000000  5000.000000
# mean           0.285483          1.210000     0.547400
# std            0.157736          1.093499     0.497798
# min            0.000723          0.000000     0.000000
# 25%            0.162971          0.000000     0.000000
# 50%            0.267933          1.000000     1.000000
# 75%            0.389612          2.000000     1.000000
# max            0.835919          8.000000     1.000000

# %%
df["default"].value_counts(normalize=True)
# Out:
# default
# 1    0.5474
# 0    0.4526
# Name: proportion, dtype: float64

# %%
df['LIMIT_BAL'] = np.round(df['LIMIT_BAL'],2)

# %%
df.head()
# Out:
#    LIMIT_BAL  AGE  SEX  EDUCATION  MARRIAGE  UTILIZATION_RATE  \
# 0  174835.71   60    1          1         1          0.086712
# 1  143086.78   21    2          1         1          0.178230
# 2  182384.43   24    1          1         2          0.358530
# 3  226151.49   50    1          1         2          0.523811
# 4  138292.33   32    2          3         3          0.322966
#
#    PAY_DELAY_MONTHS  default
# 0                 1        0
# 1                 1        1
# 2                 0        1
# 3                 0        0
# 4                 3        1

# %%
categorical_cols = ["SEX", "EDUCATION", "MARRIAGE"]

for col in categorical_cols:
    df[col] = df[col].astype("category")

# %%
X = df.drop(columns=["default"])
y = df["default"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.25,
    random_state=42,
    stratify=y
)

# %%
train_df = X_train.copy()
train_df["default"] = y_train.values

test_df = X_test.copy()
test_df["default"] = y_test.values

train_df.to_csv("../train.csv", index=False)
test_df.to_csv("../test.csv", index=False)

# %%
train_df
# Out:
#       LIMIT_BAL  AGE SEX EDUCATION MARRIAGE  UTILIZATION_RATE  \
# 1981   81019.09   25   1         2        2          0.117058
# 410   185580.74   40   2         1        1          0.664605
# 1641  220611.03   39   2         2        1          0.148998
# 2390   57690.61   33   1         1        2          0.075212
# 287   179415.86   27   2         1        2          0.280862
# ...         ...  ...  ..       ...      ...               ...
# 2033  175273.51   33   2         1        1          0.134559
# 2874  148447.05   40   2         1        2          0.268539
# 4534  187122.95   51   2         1        1          0.274860
# 696   166306.65   68   2         3        2          0.109983
# 1467  169733.58   45   1         1        1          0.549478
#
#       PAY_DELAY_MONTHS  default
# 1981                 3        1
# 410                  2        1
# 1641                 1        0
# 2390                 2        0
# 287                  1        0
# ...                ...      ...
# 2033                 2        0
# 2874                 0        1
# 4534                 4        0
# 696                  4        1
# 1467                 2        1
#
# [3750 rows x 8 columns]

# %%
test_df
# Out:
#       LIMIT_BAL  AGE SEX EDUCATION MARRIAGE  UTILIZATION_RATE  \
# 465   138951.52   35   2         2        1          0.038645
# 4481  164290.16   68   2         3        1          0.441526
# 2287  137423.06   51   1         2        2          0.116202
# 3434  263621.74   48   1         3        1          0.614774
# 554   166880.13   62   2         2        1          0.082229
# ...         ...  ...  ..       ...      ...               ...
# 3907   79659.25   52   2         2        2          0.407685
# 436   231430.78   68   2         1        2          0.464276
# 945    96495.76   42   1         2        2          0.229093
# 3947  171409.31   45   1         2        3          0.214445
# 1053  163033.69   59   1         1        1          0.435149
#
#       PAY_DELAY_MONTHS  default
# 465                  0        0
# 4481                 0        1
# 2287                 0        0
# 3434                 1        0
# 554                  0        0
# ...                ...      ...
# 3907                 0        0
# 436                  0        1
# 945                  0        0
# 3947                 0        0
# 1053                 1        0
#
# [1250 rows x 8 columns]

# %%
print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)
# Out:
# Train shape: (3750, 8)
# Test shape: (1250, 8)
